# %% [markdown]
# <a href="https://colab.research.google.com/github/canseel/gelecek-hayalim-wcode/blob/main/week4_1_homework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Gelecek Hayalim: W-Code 2.0 Veri Bilimi ve Yapay Zeka Atolyesi Homework Week 4-1**

# %% [markdown]
# Homework-1
#
# Bir sözlük oluşturulur ve bu sözlükte öğrencilerin isimleri ve Matematik, Fizik, Kimya notları tutulur. Kullanıcıdan isim ve ders ismi(Matematik, Fizik, Kimya) istenir ve bu bilgilere göre çıktı verilir.

# %%
ogrenciler = {
    "Cansel": {"Matematik": 85,
               "Fizik": 90,
               "Kimya": 78},
    "Ahmet": {"Matematik": 70,
              "Fizik": 65,
              "Kimya": 80},
    "Zeynep": {"Matematik": 92,
               "Fizik": 88,
               "Kimya": 95}
}

#şimdi her bir öğrenci için bilgileri alalım
print("Öğrenci not sistemine hoşgeldiniz!")

isim = input("Öğrencinin ismini giriniz: ")
ders = input("Öğrenci hakkında öğrenmek istediğiniz ders : ")


print(ogrenciler[isim][ders])
# Out:
# Öğrenci not sistemine hoşgeldiniz!
# Öğrencinin ismini giriniz: Cansel
# Öğrenci hakkında öğrenmek istediğiniz ders : Kimya
# 78

# %% [markdown]
# Homework 2 - Sözlük üzerinde değerleri değiştirme, yeni değer ekleme, kullanıcıya ulaşmak istediği bilgileri sorma gibi uygulamalar yapın.

# %%
ogrenciler["Kerem"]= {"Matematik": 95, "Fizik": 70, "Kimya": 50} #öge ekledik

# %%
ogrenciler
# Out:
# {'Cansel': {'Matematik': 85, 'Fizik': 90, 'Kimya': 78},
#  'Ahmet': {'Matematik': 70, 'Fizik': 65, 'Kimya': 80},
#  'Zeynep': {'Matematik': 92, 'Fizik': 88, 'Kimya': 95},
#  'Kerem': {'Matematik': 95, 'Fizik': 70, 'Kimya': 50}}

# %%
ogrenciler["Kerem"]["Fizik"]=65 #Keremin fizik notunu 70ten 65e düşürdük

# %%
ogrenciler
# Out:
# {'Cansel': {'Matematik': 85, 'Fizik': 90, 'Kimya': 78},
#  'Ahmet': {'Matematik': 70, 'Fizik': 65, 'Kimya': 80},
#  'Zeynep': {'Matematik': 92, 'Fizik': 88, 'Kimya': 95},
#  'Kerem': {'Matematik': 95, 'Fizik': 65, 'Kimya': 50}}
