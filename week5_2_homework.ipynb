# %% [markdown]
# <a href="https://colab.research.google.com/github/canseel/gelecek-hayalim-wcode/blob/main/week5_2_homework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Gelecek Hayalim: W-Code 2.0 Veri Bilimi ve Yapay Zeka Atolyesi Homework Week 5-**2**

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Homework 1
#
# Dosyayı okuyalım

# %%
df = pd.read_csv("StudentsPerformance.csv")
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
# [1000 rows x 8 columns]

# %% [markdown]
# Homework 2
#
# Kadın-Erkek sayısına bakalım

# %%
df['gender'].value_counts()
# Out:
# gender
# female    518
# male      482
# Name: count, dtype: int64

# %% [markdown]
# Homework 3
#
# Kadın-Erkek sayısına histogram grafiği ile bakalım

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
grahp_gender = sns.countplot(x='gender', data=df)
plt.figure(figsize=(18,5))
plt.show()

# %% [markdown]
# Homework 4
#
# race/ethnicity sütununda kaç farklı grup olduğuna bakalım

# %%
df['race/ethnicity'].value_counts()
# Out:
# race/ethnicity
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: count, dtype: int64

# %% [markdown]
# Homework 5
#
# Görselleştirelim

# %%
grahp_race_ethnicity = sns.countplot(x='race/ethnicity', data=df)
plt.figure(figsize=(18,5))
plt.show()

# %% [markdown]
# Homework 6
#
# parental level of education sütunundaki eşsiz değerleri bulalım

# %%
df["parental level of education"].unique()
# Out:
# array(["bachelor's degree", 'some college', "master's degree",
#        "associate's degree", 'high school', 'some high school'],
#       dtype=object)

# %% [markdown]
# Homework 7
#
# lunch sütunundaki eşsiz değerleri bulalım

# %%
df["lunch"].unique()
# Out:
# array(['standard', 'free/reduced'], dtype=object)

# %% [markdown]
# Homework 8
#
# lunch türlerinde kaçar kişi olduğunu bulalım

# %%
df["lunch"].value_counts()
# Out:
# lunch
# standard        645
# free/reduced    355
# Name: count, dtype: int64

# %% [markdown]
# Homework 9
#
# gender sütunundaki değerler için ortalama math score, reading score, writing score değerlerini bulalım.

# %%
ortalama_skorlar = df.groupby("gender")[["math score", "reading score", "writing score"]].mean()
ortalama_skorlar
# Out:
#         math score  reading score  writing score
# gender
# female   63.633205      72.608108      72.467181
# male     68.728216      65.473029      63.311203

# %% [markdown]
# Homework 10
#
# race/ethnicity sütunundaki değerler için ortalama math score, reading score, writing score değerlerini bulalım.

# %%
ortalama_skorlar2 = df.groupby("race/ethnicity")[["math score", "reading score", "writing score"]].mean()
ortalama_skorlar2
# Out:
#                 math score  reading score  writing score
# race/ethnicity
# group A          61.629213      64.674157      62.674157
# group B          63.452632      67.352632      65.600000
# group C          64.463950      69.103448      67.827586
# group D          67.362595      70.030534      70.145038
# group E          73.821429      73.028571      71.407143

# %% [markdown]
# Homework 11
#
# parental level of education sütunundaki değerler için ortalama math score, reading score, writing score değerlerini bulalım.

# %%
ortalama_skorlar3 = df.groupby("parental level of education")[["math score", "reading score", "writing score"]].mean()
ortalama_skorlar3
# Out:
#                              math score  reading score  writing score
# parental level of education
# associate's degree            67.882883      70.927928      69.896396
# bachelor's degree             69.389831      73.000000      73.381356
# high school                   62.137755      64.704082      62.448980
# master's degree               69.745763      75.372881      75.677966
# some college                  67.128319      69.460177      68.840708
# some high school              63.497207      66.938547      64.888268

# %% [markdown]
# Homework 12
#
# lunch sütunundaki değerler için ortalama math score, reading score, writing score değerlerini bulalım.

# %%
ortalama_skorlar4 = df.groupby("lunch")[["math score", "reading score", "writing score"]].mean()
ortalama_skorlar4
# Out:
#               math score  reading score  writing score
# lunch
# free/reduced   58.921127      64.653521      63.022535
# standard       70.034109      71.654264      70.823256

# %% [markdown]
# Homework 13
#
# test preparation coursesütunundaki değerler için ortalama math score, reading score, writing score değerlerini bulalım.

# %%
ortalama_skorlar5 = df.groupby("test preparation course")[["math score", "reading score", "writing score"]].mean()
ortalama_skorlar5
# Out:
#                          math score  reading score  writing score
# test preparation course
# completed                 69.695531      73.893855      74.418994
# none                      64.077882      66.534268      64.504673
